# %% [markdown]
# # O modelo SIR com PySR
#
# $$\frac{dS}{dt} = -\beta S I$$
#
# $$\frac{dI}{dt} = \beta S I - \gamma I,$$
#
# $$\frac{dR}{dt} =  \gamma I$$
#
#
# $\beta=$0.3 e $\gamma=$0.1
# ### O processo pode ser interompido assim que a expressão for encontrada

# %%
# Ative o conda no PowerShell
#      conda init powershell
# Crie um ambiente virtual
#      conda criate -n pysr
# Trabalhe no ambiente
#      conda activate pysr

# %%
import pysr
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
import sympy
import pandas as pd
import numpy as np
from pysr import PySRRegressor
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
# Importar o arquivo CSV para um DataFrame do pandas
dados = pd.read_csv('C:/Users/beatr/Desktop/GPLearn/gplearn/Scripts_Git/dados_sir.csv')
print(dados.head(2))
# Out:
#    suscetiveis  infectados  recuperado          dSdt    dIdt    dRdt
# 0        0.999    0.998999    0.998999 -2.994001e-01  0.1995  0.0999
# 1        0.001    0.001000    0.001001 -3.001198e-07 -0.0001  0.0001

# %% [markdown]
# # dSdt

# %%
# dSdt Como modelo de regressão. Selecionando os dados de entrada e saída. 
# colunas lado a lado (stacking) para formar uma matriz 2D
Xs = np.column_stack((dados.iloc[:, 0].to_numpy(),dados.iloc[:, 1].to_numpy()))  # variável independentes S e I
y_true_dSdt = dados.iloc[:, 3].to_numpy()                                        # variável dependente     dSdt

default_pysr_params = dict(
    populations=30,          # número de populações para o algoritmo evolutivo. É um conjunto de possíveis equações que evoluem em paralelo durante a busca.
    model_selection="best",  # determinar quais equações candidatas são consideradas as melhores de acordo com o menor erro
)

# Learn equations
model_dSdt = PySRRegressor(
    niterations=300,               # número de etapas de evolução, onde as equações são otimizadas.
    binary_operators=["+", "*"],   # operadores binários permitidos pelo modelo
    unary_operators=[ ],           # "cos", "exp", "sin" ...
    **default_pysr_params,
)

# Run model:
model_dSdt.fit(Xi, y_true_dSdt)

print(f"Model for 'dSdt': {model_dSdt}")
print(f"Model SymPy for 'dSdt': {model_dSdt.sympy()}")
print(f"Latex Equation for 'dSdt': {model_dSdt.latex()}")
# Out:
# C:\Users\beatr\Anaconda3\envs\pysr\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 1.720e+05
# Head worker occupation: 30.5%
# Progress: 416 / 9000 total iterations (4.622%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.988e-02  1.594e+01  y = -0.2997
# 3           2.988e-08  7.148e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.560e+05
# Head worker occupation: 23.6%
# Progress: 814 / 9000 total iterations (9.044%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.750e+05
# Head worker occupation: 25.3%
# Progress: 1282 / 9000 total iterations (14.244%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.800e+05
# Head worker occupation: 25.5%
# Progress: 1731 / 9000 total iterations (19.233%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.880e+05
# Head worker occupation: 26.2%
# Progress: 2200 / 9000 total iterations (24.444%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+05
# Head worker occupation: 26.3%
# Progress: 2640 / 9000 total iterations (29.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+05
# Head worker occupation: 27.7%
# Progress: 3055 / 9000 total iterations (33.944%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.890e+05
# Head worker occupation: 29.8%
# Progress: 3471 / 9000 total iterations (38.567%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.840e+05
# Head worker occupation: 30.0%
# Progress: 3911 / 9000 total iterations (43.456%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.840e+05
# Head worker occupation: 29.3%
# Progress: 4348 / 9000 total iterations (48.311%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.830e+05
# Head worker occupation: 30.3%
# Progress: 4767 / 9000 total iterations (52.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.840e+05
# Head worker occupation: 29.6%
# Progress: 5190 / 9000 total iterations (57.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.810e+05
# Head worker occupation: 29.5%
# Progress: 5618 / 9000 total iterations (62.422%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.992e-02  1.594e+01  y = -0.0998
# 3           2.988e-08  6.667e+00  y = x₀ * -0.2997
# 5           0.000e+00  7.971e+00  y = (x₁ * x₀) * -0.3
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.

# %% [markdown]
# # dIdt

# %%
# dIdt
# Selecionando os dados de entrada e saída. 
Xi = np.column_stack((dados.iloc[:, 0].to_numpy(),dados.iloc[:, 1].to_numpy()))  # v. independentes S e I
y_true_dIdt = dados.iloc[:, 4].to_numpy()                                        # v. resposta dIdt

default_pysr_params = dict(
    populations=300,
    model_selection="best",
)

# Learn equations
model_dIdt = PySRRegressor(
    niterations=30,
    binary_operators=["-", "*"],
    unary_operators=[],  
    **default_pysr_params,
)

# Run model:

model_dIdt.fit(Xi, y_true_dIdt)

print(f"Model for 'dIdt': {model_dIdt}")
print(f"Model SymPy for 'dIdt': {model_dIdt.sympy()}")
print(f"Latex Equation for 'dIdt': {model_dIdt.latex()}")
# Out:
# C:\Users\beatr\Anaconda3\envs\pysr\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 1.150e+05
# Head worker occupation: 46.9%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 265 / 9000 total iterations (2.944%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.131e-01  1.594e+01  y = x₀
# 3           2.989e-08  7.582e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.160e+05
# Head worker occupation: 30.4%
# Progress: 632 / 9000 total iterations (7.022%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.131e-01  1.594e+01  y = x₀
# 3           2.989e-08  7.582e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.440e+05
# Head worker occupation: 32.1%
# Progress: 1084 / 9000 total iterations (12.044%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.131e-01  1.594e+01  y = x₁
# 3           2.989e-08  7.582e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.570e+05
# Head worker occupation: 33.4%
# Progress: 1520 / 9000 total iterations (16.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.447e-02  1.594e+01  y = 0.32262
# 3           2.989e-08  7.234e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.730e+05
# Head worker occupation: 34.0%
# Progress: 1931 / 9000 total iterations (21.456%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.870e+05
# Head worker occupation: 33.4%
# Progress: 2329 / 9000 total iterations (25.878%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.850e+05
# Head worker occupation: 33.1%
# Progress: 2744 / 9000 total iterations (30.489%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.820e+05
# Head worker occupation: 33.3%
# Progress: 3176 / 9000 total iterations (35.289%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.810e+05
# Head worker occupation: 33.3%
# Progress: 3590 / 9000 total iterations (39.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.840e+05
# Head worker occupation: 32.7%
# Progress: 4015 / 9000 total iterations (44.611%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.860e+05
# Head worker occupation: 32.8%
# Progress: 4459 / 9000 total iterations (49.544%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.900e+05
# Head worker occupation: 32.7%
# Progress: 4905 / 9000 total iterations (54.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+05
# Head worker occupation: 32.4%
# Progress: 5362 / 9000 total iterations (59.578%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.930e+05
# Head worker occupation: 32.2%
# Progress: 5773 / 9000 total iterations (64.144%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.870e+05
# Head worker occupation: 32.1%
# Progress: 6181 / 9000 total iterations (68.678%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.770e+05
# Head worker occupation: 32.0%
# Progress: 6563 / 9000 total iterations (72.922%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.680e+05
# Head worker occupation: 32.1%
# Progress: 6985 / 9000 total iterations (77.611%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.650e+05
# Head worker occupation: 32.1%
# Progress: 7403 / 9000 total iterations (82.256%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.660e+05
# Head worker occupation: 32.1%
# Progress: 7814 / 9000 total iterations (86.822%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.760e+05
# Head worker occupation: 32.1%
# Progress: 8252 / 9000 total iterations (91.689%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.760e+05
# Head worker occupation: 32.0%
# Progress: 8675 / 9000 total iterations (96.389%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.849e-03  1.594e+01  y = 0.066471
# 3           2.989e-08  6.282e+00  y = 0.1997 * x₀
# 5           3.329e-09  1.097e+00  y = x₁ * (0.1999 * x₁)
# 7           7.375e-12  3.056e+00  y = ((x₀ - 0.32271) * 0.29529) * x₁
# 9           6.441e-12  6.772e-02  y = x₀ * (-0.30444 * (0.34205 - (x₁ * x₀)))
# 11          1.602e-12  6.956e-01  y = (((x₁ * x₀) - 0.33717) * (0.61273 - 0.31053)) * x₁
# 13          7.059e-23  7.971e+00  y = (((x₀ * x₀) - x₁) * 0.1) - (x₁ * (-0.2 * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# Model for 'dIdt': PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                         0.06647071
# 	1         6.299175                                    0.19969958 * x0
# 	2         1.097344                                 x1 * (0.1999 * x1)
# 	3         3.056226               ((x0 - 0.32271296) * 0.2952888) * x1
# 	4         0.067720       x0 * (-0.30444437 * (0.3420518 - (x1 * x0)))
# 	5         0.695636  (((x1 * x0) - 0.33717114) * (0.61273056 - 0.31...
# 	6  >>>>  11.922774  (((x0 * x0) - x1) * 0.10000006) - (x1 * (-0.20...
#
# 	           loss  complexity
# 	0  8.848940e-03           1
# 	1  2.988801e-08           3
# 	2  3.329327e-09           5
# 	3  7.374833e-12           7
# 	4  6.440669e-12           9
# 	5  1.602172e-12          11
# 	6  7.058608e-23          13
# ]
# Model SymPy for 'dIdt': -(-0.20000005)*x1*x1 + (x0*x0 - x1)*0.10000006
# Latex Equation for 'dIdt': - \left(-0.200\right) x_{1} x_{1} + \left(x_{0} x_{0} - x_{1}\right) 0.100

# %% [markdown]
# # dRdt

# %%
# Selecionando os dados de entrada e saída. 
X = dados.iloc[:, 1].to_numpy()  # v independentes I
Xr = X.reshape(-1, 1)
y_true = dados.iloc[:, 5].to_numpy() # dRdt
y_true_dRdt = y_true.ravel()

default_pysr_params = dict(
    populations=1,
    model_selection="best",
)

# Learn equations
model_dRdt = PySRRegressor(
    niterations=20,
    binary_operators=["+", "*"],
    unary_operators=[],  
    **default_pysr_params,
)

# Run model:

model_dRdt.fit(Xr, y_true_dRdt)

print(f"Model for 'dRdt': {model_dRdt}")
print(f"Model SymPy for 'dRdt': {model_dRdt.sympy()}")
print(f"Latex Equation for 'dRdt': {model_dRdt.latex()}")
# Out:
# C:\Users\beatr\Anaconda3\envs\pysr\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Model for 'dRdt': PySRRegressor.equations_ = [
# 	   pick  score  equation  loss  complexity
# 	0  >>>>    0.0  0.1 * x0   0.0           3
# ]
# Model SymPy for 'dRdt': 0.1*x0
# Latex Equation for 'dRdt': 0.100 x_{0}
